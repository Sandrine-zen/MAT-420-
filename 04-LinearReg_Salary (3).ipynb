# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

# %%
df = pd.read_csv("04-LinearReg_Salary.csv")
print(df.head(10))
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0
# 5           5              3.0  56643.0
# 6           6              3.1  60151.0
# 7           7              3.3  54446.0
# 8           8              3.3  64446.0
# 9           9              3.8  57190.0

# %%
X = df[["YearsExperience"]]    
y = df["Salary"] 

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)

model = LinearRegression()
model.fit(X_train, y_train)

print("\nIntercept (b0):", model.intercept_)
print("Coefficient (b1 for YearsExperience):", model.coef_[0])
# Out:
# Intercept (b0): 24380.20147947369
# Coefficient (b1 for YearsExperience): 9423.81532303098

# %%
y_pred = model.predict(X_test)
r2  = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
print("\nR² (test):", r2)
print("MSE (test):", mse)
# Out:
# R² (test): 0.9024461774180498
# MSE (test): 49830096.855908334

# %%
plt.scatter(X, y, color="blue", label="Actual Data")
plt.plot(X, model.predict(X), color="red", label="Regression Line")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Linear Regression: Salary vs YearsExperience (scikit-learn)")
plt.legend()
plt.grid(True)
plt.show()
